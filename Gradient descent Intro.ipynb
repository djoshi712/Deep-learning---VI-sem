# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Gradient?
# - If a function is decreasing at a particular point, the gradient (derivative) at that point is negative.
# - If a function is increasing at a particular point, the gradient (derivative) at that point is positive.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Note: To minimize loss (a common goal in training machine learning models), you use gradient descent.
# To maximize a function (like maximizing likelihood in some contexts), you use gradient ascent.

# %% [markdown]
# https://builtin.com/data-science/gradient-descent#:~:text=Gradient%20Descent%20is%20an%20optimization%20algorithm%20for%20finding%20a%20local,function%20as%20far%20as%20possible.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Assume we know the value of m= 78.35, then the equation becomes-
# ![image.png](attachment:image.png)
# We need to find the correct value of b for which the loss is minimized

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Note: If a function is decreasing at a particular point, the gradient (derivative) at that point is negative.
# If a function is increasing at a particular point, the gradient (derivative) at that point is positive.
